# %%
import pandas as pd
df = pd.read_csv(r"C:\Users\Usuario\Desktop\Ironhack\proyect_educ_positive\csv limpios\trasportes.csv", encoding='latin-1')
df
# Out:
#                                                     Tipo_Transporte;Año;Total
# 3: Servicios de transporte de pasajeros por fer...                        9.0
# 4: Servicios de transporte de pasajeros por car...                        4.0
# 5: Servicios de transporte de pasajeros por agu...                        9.0
# 6: Servicios de transporte aéreo de pasajeros;2...                       30.0
# 7: Servicios de alquiler de equipos de transpor...                        4.0
# 3: Servicios de transporte de pasajeros por fer...                        9.0
# 4: Servicios de transporte de pasajeros por car...                       20.0
# 5: Servicios de transporte de pasajeros por agu...                        2.0
# 6: Servicios de transporte aéreo de pasajeros;2...                       60.0
# 7: Servicios de alquiler de equipos de transpor...                       60.0
# 3: Servicios de transporte de pasajeros por fer...                        2.0
# ...

# %%
import pandas as pd

df = pd.read_csv(r"C:\Users\Usuario\Desktop\Ironhack\proyect_educ_positive\csv limpios\trasportes.csv", encoding='latin-1')

df['Año'] = df.iloc[:, 0].str[:4]

df
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[8], line 5
#       1 import pandas as pd
#       3 df = pd.read_csv(r"C:\Users\Usuario\Desktop\Ironhack\proyect_educ_positive\csv limpios\trasportes.csv", encoding='latin-1')
# ----> 5 df['Año'] = df.iloc[:, 0].str[:4]
#       7 df
#
# File ~\anaconda3\lib\site-packages\pandas\core\generic.py:5902, in NDFrame.__getattr__(self, name)
#    5895 if (
#    5896     name not in self._internal_names_set
#    5897     and name not in self._metadata
#    5898     and name not in self._accessors
#    5899     and self._info_axis._can_hold_identifiers_and_holds_name(name)
#    5900 ):
#    5901     return self[name]
# -> 5902 return object.__getattribute__(self, name)
#
# File ~\anaconda3\lib\site-packages\pandas\core\accessor.py:182, in CachedAccessor.__get__(self, obj, cls)
#     179 if obj is None:
# ...

# %%
df['Año'] = df.iloc[:, 0].str[:4]
df.head
